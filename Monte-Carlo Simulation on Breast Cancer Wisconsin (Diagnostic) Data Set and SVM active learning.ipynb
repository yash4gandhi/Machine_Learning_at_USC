# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.svm import LinearSVC
from sklearn import preprocessing
from sklearn.cluster import KMeans, SpectralClustering
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import roc_auc_score,confusion_matrix,ConfusionMatrixDisplay,accuracy_score, roc_curve, auc, precision_score, recall_score, confusion_matrix, f1_score
from sklearn.metrics.pairwise import euclidean_distances

# %%
columns = ['Id', 'Diagnosis']
features = ['radius', 'texture', 'perimeter', 'area', 'smoothness', 'compactness', 'concavity', 'concave points', 'symmetry','fractal dimension']
measure = ['mean', 'std', 'worst']

# %%
for i in measure:
    for j in features:
        columns.append(i+'_'+j)
len(columns)
# Out:
# 32

# %%
df = pd.read_csv("../data/wdbc.data",names = columns, header = None, sep = ',')
df.head(3)
# Out:
#          Id Diagnosis  mean_radius  mean_texture  mean_perimeter  mean_area  \
# 0    842302         M        17.99         10.38           122.8     1001.0
# 1    842517         M        20.57         17.77           132.9     1326.0
# 2  84300903         M        19.69         21.25           130.0     1203.0
#
#    mean_smoothness  mean_compactness  mean_concavity  mean_concave points  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
#
#    ...  worst_radius  worst_texture  worst_perimeter  worst_area  \
# 0  ...         25.38          17.33            184.6      2019.0
# 1  ...         24.99          23.41            158.8      1956.0
# 2  ...         23.57          25.53            152.5      1709.0
#
#    worst_smoothness  worst_compactness  worst_concavity  worst_concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
#
#    worst_symmetry  worst_fractal dimension
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
#
# [3 rows x 32 columns]

# %%
df.shape
# Out:
# (569, 32)

# %%
finalfeatures = columns.copy()
finalfeatures.remove('Id')
finalfeatures.remove('Diagnosis')

# %%
ms = preprocessing.MinMaxScaler()
newdf = ms.fit_transform(df[finalfeatures])

# %%
newdf = pd.DataFrame(newdf, columns=finalfeatures)
newdf = pd.concat([newdf, df['Diagnosis']], axis=1)

# %%
newdf = newdf.replace("B", 0) 
newdf = newdf.replace("M", 1)

# %%
malignant = newdf[newdf['Diagnosis'] == 1]
benign = newdf[newdf['Diagnosis'] == 0]

# %%
import operator

# %%
final_report3 = [['Simulation','Train Accuracy','Train Precision','Train Recall', 'Train F1score', 'Train AUC', 'Test Accuracy','Test Precision','Test Recall', 'Test F1score', 'Test AUC']]

# %%
for i in range(1,31):
    train_m, test_m = train_test_split(malignant, test_size = 0.2)
    train_b, test_b = train_test_split(benign, test_size = 0.2)
    train = pd.concat([train_m,train_b], axis = 0)
    test = pd.concat([test_m,test_b], axis = 0)
    temp = train.copy()
    new_train = train.copy()
    
    km = KMeans(n_clusters = 2, init = 'random', n_init = 20)
    km.fit(train[finalfeatures])
 
    cluster_distance = euclidean_distances(train[finalfeatures], km.cluster_centers_)
    list_distance = cluster_distance.tolist()
    cl1 = []
    cl2 = []
    for x in list_distance:
        cl1.append(x[0])
        cl2.append(x[1])
        
    temp['cl1'] = cl1
    temp['cl2'] = cl2
    
    newtemp1 = temp.sort_values(by='cl1').iloc[:30]
    newtemp2 = temp.sort_values(by='cl2').iloc[:30]
    label1 = newtemp1['Diagnosis'].value_counts().index[0]
    label2 = newtemp2['Diagnosis'].value_counts().index[0]
    
    new_train['Assigned_Cluster'] = km.labels_
    new_train['Assigned_Diagnosis'] = ""
    for k in range(len(new_train)):
        if new_train['Assigned_Cluster'].iloc[k] == 0:
            new_train['Assigned_Diagnosis'].iloc[k] = label1
        else:
            new_train['Assigned_Diagnosis'].iloc[k] = label2 
    new_train['Assigned_Diagnosis'] = new_train['Assigned_Diagnosis'].astype(str).astype(int)
    
    
    new_test = test.copy()
    cluster_distance = euclidean_distances(test[finalfeatures], km.cluster_centers_)
    list_distance = cluster_distance.tolist()
    cl1 = []
    cl2 = []
    for x in list_distance:
        cl1.append(x[0])
        cl2.append(x[1])
        
    new_test['cl1'] = cl1
    new_test['cl2'] = cl2
    
    new_test['Assigned_Diagnosis'] = ""
    for k in range(len(new_test)):
        if new_test['cl1'].iloc[k] < new_test['cl2'].iloc[k]:
            new_test['Assigned_Diagnosis'].iloc[k] = label1
        else:
            new_test['Assigned_Diagnosis'].iloc[k] = label2
    new_test['Assigned_Diagnosis'] = new_test['Assigned_Diagnosis'].astype(str).astype(int)
    
    
    train_pred_y = new_train['Assigned_Diagnosis']
    test_pred_y = new_test['Assigned_Diagnosis']
    train_y = new_train['Diagnosis']
    test_y = new_test['Diagnosis']
    

    train_acc = accuracy_score(train_y, train_pred_y)
    train_precision = precision_score(train_y, train_pred_y)
    train_recall = recall_score(train_y, train_pred_y)
    train_f1score = f1_score(train_y, train_pred_y)
    train_auc = roc_auc_score(train_y, train_pred_y)
    
    test_acc = accuracy_score(test_y, test_pred_y)
    test_precision = precision_score(test_y, test_pred_y)
    test_recall = recall_score(test_y, test_pred_y)
    test_f1score = f1_score(test_y, test_pred_y)
    test_auc = roc_auc_score(test_y, test_pred_y)
    
    final_report3.append([i,train_acc,train_precision,train_recall,train_f1score,train_auc,test_acc,test_precision ,test_recall,test_f1score,test_auc])
    print("Simulation: ", i)
    print('Train Accuracy: ',train_acc,', Train Precision: ',train_precision,', Train Recall: ',train_recall, ', Train F1score: ', train_f1score,', Train AUC:',train_auc) 
    print('Test Accuracy: ',test_acc,', Test Precision: ',test_precision,', Test Recall: ',test_recall, ', Test F1score: ', test_f1score,', Test AUC:',test_auc) 
    print()
# Out:
# Simulation:  1
# Train Accuracy:  0.920704845814978 , Train Precision:  0.9463087248322147 , Train Recall:  0.834319526627219 , Train F1score:  0.8867924528301887 , Train AUC: 0.9031246755943113
# Test Accuracy:  0.9478260869565217 , Test Precision:  0.9512195121951219 , Test Recall:  0.9069767441860465 , Test F1score:  0.9285714285714286 , Test AUC: 0.9395994832041343
#
# Simulation:  2
# Train Accuracy:  0.9229074889867841 , Train Precision:  0.9466666666666667 , Train Recall:  0.8402366863905325 , Train F1score:  0.890282131661442 , Train AUC: 0.9060832554759679
# Test Accuracy:  0.9478260869565217 , Test Precision:  0.9743589743589743 , Test Recall:  0.8837209302325582 , Test F1score:  0.9268292682926831 , Test AUC: 0.9349160206718348
#
# Simulation:  3
# Train Accuracy:  0.9140969162995595 , Train Precision:  0.9452054794520548 , Train Recall:  0.8165680473372781 , Train F1score:  0.8761904761904762 , Train AUC: 0.8942489359493407
# Test Accuracy:  0.9565217391304348 , Test Precision:  0.975 , Test Recall:  0.9069767441860465 , Test F1score:  0.9397590361445783 , Test AUC: 0.9465439276485788
#
# Simulation:  4
# Train Accuracy:  0.9383259911894273 , Train Precision:  0.9795918367346939 , Train Recall:  0.8520710059171598 , Train F1score:  0.9113924050632911 , Train AUC: 0.920772345063843
# Test Accuracy:  0.9130434782608695 , Test Precision:  0.9230769230769231 , Test Recall:  0.8372093023255814 , Test F1score:  0.878048780487805 , Test AUC: 0.8977713178294575
#
# Simulation:  5
# Train Accuracy:  0.9251101321585903 , Train Precision:  0.9411764705882353 , Train Recall:  0.8520710059171598 , Train F1score:  0.8944099378881987 , Train AUC: 0.9102460292743694
# Test Accuracy:  0.9217391304347826 , Test Precision:  0.9473684210526315 , Test Recall:  0.8372093023255814 , Test F1score:  0.8888888888888888 , Test AUC: 0.9047157622739019
#
# Simulation:  6
# Train Accuracy:  0.9251101321585903 , Train Precision:  0.9530201342281879 , Train Recall:  0.8402366863905325 , Train F1score:  0.8930817610062892 , Train AUC: 0.9078376414408803
# Test Accuracy:  0.9391304347826087 , Test Precision:  0.95 , Test Recall:  0.8837209302325582 , Test F1score:  0.9156626506024096 , Test AUC: 0.9279715762273901
#
# Simulation:  7
# Train Accuracy:  0.9185022026431718 , Train Precision:  0.9459459459459459 , Train Recall:  0.8284023668639053 , Train F1score:  0.8832807570977919 , Train AUC: 0.9001660957126545
# Test Accuracy:  0.9478260869565217 , Test Precision:  0.9302325581395349 , Test Recall:  0.9302325581395349 , Test F1score:  0.9302325581395349 , Test AUC: 0.9442829457364341
#
# Simulation:  8
# Train Accuracy:  0.9229074889867841 , Train Precision:  0.958904109589041 , Train Recall:  0.8284023668639053 , Train F1score:  0.8888888888888887 , Train AUC: 0.903674867642479
# Test Accuracy:  0.9391304347826087 , Test Precision:  0.9285714285714286 , Test Recall:  0.9069767441860465 , Test F1score:  0.9176470588235294 , Test AUC: 0.9326550387596899
#
# Simulation:  9
# Train Accuracy:  0.9273127753303965 , Train Precision:  0.9594594594594594 , Train Recall:  0.8402366863905325 , Train F1score:  0.8958990536277601 , Train AUC: 0.9095920274057926
# Test Accuracy:  0.9478260869565217 , Test Precision:  0.9743589743589743 , Test Recall:  0.8837209302325582 , Test F1score:  0.9268292682926831 , Test AUC: 0.9349160206718348
#
# Simulation:  10
# Train Accuracy:  0.9361233480176211 , Train Precision:  0.9605263157894737 , Train Recall:  0.863905325443787 , Train F1score:  0.9096573208722741 , Train AUC: 0.9214263469324199
# Test Accuracy:  0.8956521739130435 , Test Precision:  0.918918918918919 , Test Recall:  0.7906976744186046 , Test F1score:  0.85 , Test AUC: 0.8745155038759691
#
# Simulation:  11
# Train Accuracy:  0.9295154185022027 , Train Precision:  0.9659863945578231 , Train Recall:  0.8402366863905325 , Train F1score:  0.8987341772151898 , Train AUC: 0.9113464133707047
# Test Accuracy:  0.9217391304347826 , Test Precision:  0.9047619047619048 , Test Recall:  0.8837209302325582 , Test F1score:  0.8941176470588236 , Test AUC: 0.9140826873385013
#
# Simulation:  12
# Train Accuracy:  0.9295154185022027 , Train Precision:  0.9724137931034482 , Train Recall:  0.834319526627219 , Train F1score:  0.8980891719745223 , Train AUC: 0.9101422194539603
# Test Accuracy:  0.9391304347826087 , Test Precision:  0.9736842105263158 , Test Recall:  0.8604651162790697 , Test F1score:  0.9135802469135803 , Test AUC: 0.9232881136950905
#
# Simulation:  13
# Train Accuracy:  0.920704845814978 , Train Precision:  0.9290322580645162 , Train Recall:  0.8520710059171598 , Train F1score:  0.888888888888889 , Train AUC: 0.9067372573445447
# Test Accuracy:  0.9304347826086956 , Test Precision:  0.972972972972973 , Test Recall:  0.8372093023255814 , Test F1score:  0.9 , Test AUC: 0.9116602067183464
#
# Simulation:  14
# Train Accuracy:  0.9251101321585903 , Train Precision:  0.9354838709677419 , Train Recall:  0.8579881656804734 , Train F1score:  0.8950617283950617 , Train AUC: 0.9114502231911139
# Test Accuracy:  0.9217391304347826 , Test Precision:  0.9722222222222222 , Test Recall:  0.813953488372093 , Test F1score:  0.8860759493670887 , Test AUC: 0.9000322997416023
#
# Simulation:  15
# Train Accuracy:  0.9273127753303965 , Train Precision:  0.9594594594594594 , Train Recall:  0.8402366863905325 , Train F1score:  0.8958990536277601 , Train AUC: 0.9095920274057926
# Test Accuracy:  0.9217391304347826 , Test Precision:  0.925 , Test Recall:  0.8604651162790697 , Test F1score:  0.891566265060241 , Test AUC: 0.9093992248062016
#
# Simulation:  16
# Train Accuracy:  0.9295154185022027 , Train Precision:  0.9790209790209791 , Train Recall:  0.8284023668639053 , Train F1score:  0.8974358974358975 , Train AUC: 0.9089380255372158
# Test Accuracy:  0.9391304347826087 , Test Precision:  0.9285714285714286 , Test Recall:  0.9069767441860465 , Test F1score:  0.9176470588235294 , Test AUC: 0.9326550387596899
#
# Simulation:  17
# Train Accuracy:  0.933920704845815 , Train Precision:  0.9483870967741935 , Train Recall:  0.8698224852071006 , Train F1score:  0.9074074074074073 , Train AUC: 0.9208761548842521
# Test Accuracy:  0.9043478260869565 , Test Precision:  0.9705882352941176 , Test Recall:  0.7674418604651163 , Test F1score:  0.8571428571428571 , Test AUC: 0.8767764857881137
#
# Simulation:  18
# Train Accuracy:  0.9273127753303965 , Train Precision:  0.9533333333333334 , Train Recall:  0.8461538461538461 , Train F1score:  0.896551724137931 , Train AUC: 0.9107962213225372
# Test Accuracy:  0.9304347826086956 , Test Precision:  0.9487179487179487 , Test Recall:  0.8604651162790697 , Test F1score:  0.9024390243902439 , Test AUC: 0.9163436692506459
#
# Simulation:  19
# Train Accuracy:  0.9273127753303965 , Train Precision:  0.9788732394366197 , Train Recall:  0.8224852071005917 , Train F1score:  0.8938906752411576 , Train AUC: 0.905979445655559
# Test Accuracy:  0.9391304347826087 , Test Precision:  0.9736842105263158 , Test Recall:  0.8604651162790697 , Test F1score:  0.9135802469135803 , Test AUC: 0.9232881136950905
#
# Simulation:  20
# Train Accuracy:  0.933920704845815 , Train Precision:  0.954248366013072 , Train Recall:  0.863905325443787 , Train F1score:  0.9068322981366459 , Train AUC: 0.9196719609675076
# Test Accuracy:  0.8782608695652174 , Test Precision:  0.8717948717948718 , Test Recall:  0.7906976744186046 , Test F1score:  0.8292682926829267 , Test AUC: 0.8606266149870802
#
# Simulation:  21
# Train Accuracy:  0.9383259911894273 , Train Precision:  0.9490445859872612 , Train Recall:  0.8816568047337278 , Train F1score:  0.9141104294478528 , Train AUC: 0.9267933146475655
# Test Accuracy:  0.8869565217391304 , Test Precision:  0.96875 , Test Recall:  0.7209302325581395 , Test F1score:  0.8266666666666667 , Test AUC: 0.8535206718346253
#
# Simulation:  22
# Train Accuracy:  0.920704845814978 , Train Precision:  0.9463087248322147 , Train Recall:  0.834319526627219 , Train F1score:  0.8867924528301887 , Train AUC: 0.9031246755943113
# Test Accuracy:  0.9565217391304348 , Test Precision:  0.975 , Test Recall:  0.9069767441860465 , Test F1score:  0.9397590361445783 , Test AUC: 0.9465439276485788
#
# Simulation:  23
# Train Accuracy:  0.9229074889867841 , Train Precision:  0.958904109589041 , Train Recall:  0.8284023668639053 , Train F1score:  0.8888888888888887 , Train AUC: 0.903674867642479
# Test Accuracy:  0.9217391304347826 , Test Precision:  0.925 , Test Recall:  0.8604651162790697 , Test F1score:  0.891566265060241 , Test AUC: 0.9093992248062016
# Simulation:  24
# Train Accuracy:  0.9317180616740088 , Train Precision:  0.9539473684210527 , Train Recall:  0.8579881656804734 , Train F1score:  0.9034267912772586 , Train AUC: 0.9167133810858509
# Test Accuracy:  0.9130434782608695 , Test Precision:  0.9459459459459459 , Test Recall:  0.813953488372093 , Test F1score:  0.875 , Test AUC: 0.8930878552971576
#
# Simulation:  25
# Train Accuracy:  0.9317180616740088 , Train Precision:  0.9791666666666666 , Train Recall:  0.834319526627219 , Train F1score:  0.9009584664536742 , Train AUC: 0.9118966054188726
# Test Accuracy:  0.9304347826086956 , Test Precision:  0.926829268292683 , Test Recall:  0.8837209302325582 , Test F1score:  0.9047619047619047 , Test AUC: 0.9210271317829458
#
# Simulation:  26
# Train Accuracy:  0.9273127753303965 , Train Precision:  0.9657534246575342 , Train Recall:  0.834319526627219 , Train F1score:  0.8952380952380953 , Train AUC: 0.9083878334890481
# Test Accuracy:  0.9304347826086956 , Test Precision:  0.9069767441860465 , Test Recall:  0.9069767441860465 , Test F1score:  0.9069767441860465 , Test AUC: 0.9257105943152454
#
# Simulation:  27
# Train Accuracy:  0.9317180616740088 , Train Precision:  0.9726027397260274 , Train Recall:  0.8402366863905325 , Train F1score:  0.9015873015873015 , Train AUC: 0.913100799335617
# Test Accuracy:  0.9304347826086956 , Test Precision:  0.926829268292683 , Test Recall:  0.8837209302325582 , Test F1score:  0.9047619047619047 , Test AUC: 0.9210271317829458
#
# Simulation:  28
# Train Accuracy:  0.9295154185022027 , Train Precision:  0.9536423841059603 , Train Recall:  0.8520710059171598 , Train F1score:  0.9000000000000001 , Train AUC: 0.913754801204194
# Test Accuracy:  0.9217391304347826 , Test Precision:  0.9473684210526315 , Test Recall:  0.8372093023255814 , Test F1score:  0.8888888888888888 , Test AUC: 0.9047157622739019
#
# Simulation:  29
# Train Accuracy:  0.9295154185022027 , Train Precision:  0.9419354838709677 , Train Recall:  0.863905325443787 , Train F1score:  0.9012345679012346 , Train AUC: 0.916163189037683
# Test Accuracy:  0.9043478260869565 , Test Precision:  0.9444444444444444 , Test Recall:  0.7906976744186046 , Test F1score:  0.8607594936708861 , Test AUC: 0.8814599483204134
#
# Simulation:  30
# Train Accuracy:  0.9317180616740088 , Train Precision:  0.9539473684210527 , Train Recall:  0.8579881656804734 , Train F1score:  0.9034267912772586 , Train AUC: 0.9167133810858509
# Test Accuracy:  0.9130434782608695 , Test Precision:  0.9459459459459459 , Test Recall:  0.813953488372093 , Test F1score:  0.875 , Test AUC: 0.8930878552971576

# %%
ConfusionMatrixDisplay(confusion_matrix(train_y,  train_pred_y)).plot()

# %%
fpr, tpr, _ = roc_curve(train_y,  train_pred_y)        
plt.plot(fpr,tpr,color ='green', label='ROC with AUC: ' + str(roc_auc_score(train_y, train_pred_y)))
plt.plot([0, 1], [0, 1], color='grey', linestyle = 'dotted')
plt.xlabel('FALSE Positive RATE')
plt.ylabel('TRUE Positive RATE')
plt.title('ROC CURVE FOR TRAINING DATA')
plt.legend()
plt.show()

# %%
ConfusionMatrixDisplay(confusion_matrix(test_y,  test_pred_y)).plot()

# %%
fpr, tpr, _ = roc_curve(test_y,  test_pred_y)        
plt.plot(fpr,tpr,color ='green', label='ROC with AUC: ' + str(roc_auc_score(test_y, test_pred_y)))
plt.plot([0, 1], [0, 1], color='grey', linestyle = 'dotted')
plt.xlabel('FALSE Positive RATE')
plt.ylabel('TRUE Positive RATE')
plt.title('ROC CURVE FOR Testing data')
plt.legend()
plt.show()

# %%
reportdf3 = pd.DataFrame(final_report3[1:], columns = final_report3[0])
reportdf3

# %%
reportdf3.mean()

# %%
final_report4 = [['Simulation','Train Accuracy','Train Precision','Train Recall', 'Train F1score', 'Train AUC', 'Test Accuracy','Test Precision','Test Recall', 'Test F1score', 'Test AUC']]

# %%
for k in range(1,31):
    train_m, test_m = train_test_split(malignant, test_size = 0.2)
    train_b, test_b = train_test_split(benign, test_size = 0.2)
    train = pd.concat([train_m,train_b], axis = 0)
    test = pd.concat([test_m,test_b], axis = 0)
    new_train = train.copy()
    new_test = test.copy()
    
    sc = SpectralClustering(n_clusters=2, n_init=20, gamma=1.0, affinity='rbf')   
    new_train['Assigned_Cluster'] = sc.fit_predict(train[finalfeatures])
    
    for i in range (0,2):
        diagnosis = new_train[new_train.Assigned_Cluster == i]['Diagnosis'].value_counts().index[0]
        new_train.loc[new_train.Assigned_Cluster == i, 'Assigned_Diagnosis'] = diagnosis

    new_train['Assigned_Diagnosis'] = new_train['Assigned_Diagnosis'].astype(int)
    
    
    new_test['Assigned_Cluster'] = sc.fit_predict(test[finalfeatures])   
    for i in range (0,2):
        diagnosis = new_test[new_test.Assigned_Cluster == i]['Diagnosis'].value_counts().index[0]
        new_test.loc[new_test.Assigned_Cluster == i, 'Assigned_Diagnosis'] = diagnosis
    new_test['Assigned_Diagnosis'] = new_test['Assigned_Diagnosis'].astype(int)
    
    
    train_pred_y = new_train['Assigned_Diagnosis']
    test_pred_y = new_test['Assigned_Diagnosis']
    train_y = new_train['Diagnosis']
    test_y = new_test['Diagnosis']
    

    train_acc = accuracy_score(train_y, train_pred_y)
    train_precision = precision_score(train_y, train_pred_y)
    train_recall = recall_score(train_y, train_pred_y)
    train_f1score = f1_score(train_y, train_pred_y)
    train_auc = roc_auc_score(train_y, train_pred_y)
    
    test_acc = accuracy_score(test_y, test_pred_y)
    test_precision = precision_score(test_y, test_pred_y)
    test_recall = recall_score(test_y, test_pred_y)
    test_f1score = f1_score(test_y, test_pred_y)
    test_auc = roc_auc_score(test_y, test_pred_y)
    
    final_report4.append([k,train_acc,train_precision,train_recall,train_f1score,train_auc,test_acc,test_precision ,test_recall,test_f1score,test_auc])
    print("Simulation: ", k)
    print('Train Accuracy: ',train_acc,', Train Precision: ',train_precision,', Train Recall: ',train_recall, ', Train F1score: ', train_f1score,', Train AUC:',train_auc) 
    print('Test Accuracy: ',test_acc,', Test Precision: ',test_precision,', Test Recall: ',test_recall, ', Test F1score: ', test_f1score,', Test AUC:',test_auc) 
    print()
# Out:
# Simulation:  1
# Train Accuracy:  0.8678414096916299 , Train Precision:  0.9823008849557522 , Train Recall:  0.6568047337278107 , Train F1score:  0.7872340425531915 , Train AUC: 0.8248935949340808
# Test Accuracy:  0.8869565217391304 , Test Precision:  0.96875 , Test Recall:  0.7209302325581395 , Test F1score:  0.8266666666666667 , Test AUC: 0.8535206718346253
#
# Simulation:  2
# Train Accuracy:  0.8744493392070485 , Train Precision:  0.9745762711864406 , Train Recall:  0.6804733727810651 , Train F1score:  0.8013937282229965 , Train AUC: 0.8349735284957958
# Test Accuracy:  0.782608695652174 , Test Precision:  1.0 , Test Recall:  0.4186046511627907 , Test F1score:  0.5901639344262295 , Test AUC: 0.7093023255813954
#
# Simulation:  3
# Train Accuracy:  0.8898678414096917 , Train Precision:  0.976 , Train Recall:  0.7218934911242604 , Train F1score:  0.8299319727891156 , Train AUC: 0.8556835876673934
# Test Accuracy:  0.7391304347826086 , Test Precision:  1.0 , Test Recall:  0.3023255813953488 , Test F1score:  0.46428571428571425 , Test AUC: 0.6511627906976745
#
# Simulation:  4
# Train Accuracy:  0.8524229074889867 , Train Precision:  0.9811320754716981 , Train Recall:  0.6153846153846154 , Train F1score:  0.7563636363636365 , Train AUC: 0.8041835357624831
# Test Accuracy:  0.8695652173913043 , Test Precision:  0.9666666666666667 , Test Recall:  0.6744186046511628 , Test F1score:  0.7945205479452055 , Test AUC: 0.830264857881137
#
# Simulation:  5
# Train Accuracy:  0.8392070484581498 , Train Precision:  0.9897959183673469 , Train Recall:  0.5739644970414202 , Train F1score:  0.7265917602996255 , Train AUC: 0.7852278625557978
# Test Accuracy:  0.9217391304347826 , Test Precision:  1.0 , Test Recall:  0.7906976744186046 , Test F1score:  0.8831168831168831 , Test AUC: 0.8953488372093024
#
# Simulation:  6
# Train Accuracy:  0.8590308370044053 , Train Precision:  0.981651376146789 , Train Recall:  0.6331360946745562 , Train F1score:  0.7697841726618705 , Train AUC: 0.8130592754074535
# Test Accuracy:  0.8521739130434782 , Test Precision:  0.9642857142857143 , Test Recall:  0.627906976744186 , Test F1score:  0.7605633802816901 , Test AUC: 0.8070090439276486
#
# Simulation:  7
# Train Accuracy:  0.8480176211453745 , Train Precision:  1.0 , Train Recall:  0.591715976331361 , Train F1score:  0.7434944237918216 , Train AUC: 0.7958579881656804
# Test Accuracy:  0.9217391304347826 , Test Precision:  0.9473684210526315 , Test Recall:  0.8372093023255814 , Test F1score:  0.8888888888888888 , Test AUC: 0.9047157622739019
#
# Simulation:  8
# Train Accuracy:  0.8656387665198237 , Train Precision:  0.9736842105263158 , Train Recall:  0.6568047337278107 , Train F1score:  0.784452296819788 , Train AUC: 0.8231392089691684
# Test Accuracy:  0.8260869565217391 , Test Precision:  1.0 , Test Recall:  0.5348837209302325 , Test F1score:  0.6969696969696969 , Test AUC: 0.7674418604651163
#
# Simulation:  9
# Train Accuracy:  0.8634361233480177 , Train Precision:  0.9734513274336283 , Train Recall:  0.650887573964497 , Train F1score:  0.7801418439716311 , Train AUC: 0.8201806290875117
# Test Accuracy:  0.8608695652173913 , Test Precision:  1.0 , Test Recall:  0.627906976744186 , Test F1score:  0.7714285714285715 , Test AUC: 0.813953488372093
#
# Simulation:  10
# Train Accuracy:  0.8458149779735683 , Train Precision:  0.9805825242718447 , Train Recall:  0.5976331360946746 , Train F1score:  0.7426470588235294 , Train AUC: 0.7953077961175128
# Test Accuracy:  0.8869565217391304 , Test Precision:  0.96875 , Test Recall:  0.7209302325581395 , Test F1score:  0.8266666666666667 , Test AUC: 0.8535206718346253
#
# Simulation:  11
# Train Accuracy:  0.8612334801762115 , Train Precision:  0.9818181818181818 , Train Recall:  0.6390532544378699 , Train F1score:  0.7741935483870968 , Train AUC: 0.8160178552891104
# Test Accuracy:  0.6956521739130435 , Test Precision:  1.0 , Test Recall:  0.18604651162790697 , Test F1score:  0.3137254901960785 , Test AUC: 0.5930232558139534
#
# Simulation:  12
# Train Accuracy:  0.8590308370044053 , Train Precision:  0.9906542056074766 , Train Recall:  0.6272189349112426 , Train F1score:  0.7681159420289855 , Train AUC: 0.8118550814907091
# Test Accuracy:  0.8869565217391304 , Test Precision:  1.0 , Test Recall:  0.6976744186046512 , Test F1score:  0.8219178082191781 , Test AUC: 0.8488372093023255
#
# Simulation:  13
# Train Accuracy:  0.8083700440528634 , Train Precision:  0.9880952380952381 , Train Recall:  0.4911242603550296 , Train F1score:  0.6561264822134387 , Train AUC: 0.7438077442126025
# Test Accuracy:  0.8956521739130435 , Test Precision:  1.0 , Test Recall:  0.7209302325581395 , Test F1score:  0.8378378378378378 , Test AUC: 0.8604651162790697
#
# Simulation:  14
# Train Accuracy:  0.8524229074889867 , Train Precision:  0.9722222222222222 , Train Recall:  0.621301775147929 , Train F1score:  0.7581227436823104 , Train AUC: 0.8053877296792276
# Test Accuracy:  0.9130434782608695 , Test Precision:  1.0 , Test Recall:  0.7674418604651163 , Test F1score:  0.868421052631579 , Test AUC: 0.8837209302325582
#
# Simulation:  15
# Train Accuracy:  0.8722466960352423 , Train Precision:  0.9826086956521739 , Train Recall:  0.6686390532544378 , Train F1score:  0.795774647887324 , Train AUC: 0.8308107546973944
# Test Accuracy:  0.8173913043478261 , Test Precision:  0.9583333333333334 , Test Recall:  0.5348837209302325 , Test F1score:  0.6865671641791045 , Test AUC: 0.760497416020672
#
# Simulation:  16
# Train Accuracy:  0.8524229074889867 , Train Precision:  0.9903846153846154 , Train Recall:  0.6094674556213018 , Train F1score:  0.7545787545787546 , Train AUC: 0.8029793418457386
# Test Accuracy:  0.8608695652173913 , Test Precision:  0.9354838709677419 , Test Recall:  0.6744186046511628 , Test F1score:  0.7837837837837838 , Test AUC: 0.8233204134366924
#
# Simulation:  17
# Train Accuracy:  0.8590308370044053 , Train Precision:  0.972972972972973 , Train Recall:  0.6390532544378699 , Train F1score:  0.7714285714285716 , Train AUC: 0.8142634693241981
# Test Accuracy:  0.9130434782608695 , Test Precision:  1.0 , Test Recall:  0.7674418604651163 , Test F1score:  0.868421052631579 , Test AUC: 0.8837209302325582
#
# Simulation:  18
# Train Accuracy:  0.8458149779735683 , Train Precision:  0.9805825242718447 , Train Recall:  0.5976331360946746 , Train F1score:  0.7426470588235294 , Train AUC: 0.7953077961175128
# Test Accuracy:  0.9478260869565217 , Test Precision:  0.9743589743589743 , Test Recall:  0.8837209302325582 , Test F1score:  0.9268292682926831 , Test AUC: 0.9349160206718348
#
# Simulation:  19
# Train Accuracy:  0.8502202643171806 , Train Precision:  0.9902912621359223 , Train Recall:  0.6035502958579881 , Train F1score:  0.7499999999999999 , Train AUC: 0.8000207619640818
# Test Accuracy:  0.9217391304347826 , Test Precision:  0.9473684210526315 , Test Recall:  0.8372093023255814 , Test F1score:  0.8888888888888888 , Test AUC: 0.9047157622739019
#
# Simulation:  20
# Train Accuracy:  0.8568281938325991 , Train Precision:  0.9727272727272728 , Train Recall:  0.6331360946745562 , Train F1score:  0.7670250896057348 , Train AUC: 0.8113048894425412
# Test Accuracy:  0.8695652173913043 , Test Precision:  1.0 , Test Recall:  0.6511627906976745 , Test F1score:  0.7887323943661972 , Test AUC: 0.8255813953488372
#
# Simulation:  21
# Train Accuracy:  0.8524229074889867 , Train Precision:  0.9722222222222222 , Train Recall:  0.621301775147929 , Train F1score:  0.7581227436823104 , Train AUC: 0.8053877296792276
# Test Accuracy:  0.9130434782608695 , Test Precision:  1.0 , Test Recall:  0.7674418604651163 , Test F1score:  0.868421052631579 , Test AUC: 0.8837209302325582
#
# Simulation:  22
# Train Accuracy:  0.8634361233480177 , Train Precision:  0.9734513274336283 , Train Recall:  0.650887573964497 , Train F1score:  0.7801418439716311 , Train AUC: 0.8201806290875117
# Test Accuracy:  0.8347826086956521 , Test Precision:  1.0 , Test Recall:  0.5581395348837209 , Test F1score:  0.7164179104477612 , Test AUC: 0.7790697674418605
#
# Simulation:  23
# Train Accuracy:  0.8502202643171806 , Train Precision:  0.9719626168224299 , Train Recall:  0.6153846153846154 , Train F1score:  0.7536231884057971 , Train AUC: 0.8024291497975709
# Test Accuracy:  0.9217391304347826 , Test Precision:  1.0 , Test Recall:  0.7906976744186046 , Test F1score:  0.8831168831168831 , Test AUC: 0.8953488372093024
#
# Simulation:  24
# Train Accuracy:  0.8546255506607929 , Train Precision:  0.9813084112149533 , Train Recall:  0.621301775147929 , Train F1score:  0.7608695652173911 , Train AUC: 0.8071421156441398
# Test Accuracy:  0.8695652173913043 , Test Precision:  0.9666666666666667 , Test Recall:  0.6744186046511628 , Test F1score:  0.7945205479452055 , Test AUC: 0.830264857881137
# Simulation:  25
# Train Accuracy:  0.8480176211453745 , Train Precision:  0.9901960784313726 , Train Recall:  0.5976331360946746 , Train F1score:  0.7453874538745388 , Train AUC: 0.7970621820824251
# Test Accuracy:  0.9304347826086956 , Test Precision:  0.972972972972973 , Test Recall:  0.8372093023255814 , Test F1score:  0.9 , Test AUC: 0.9116602067183464
#
# Simulation:  26
# Train Accuracy:  0.8524229074889867 , Train Precision:  0.9811320754716981 , Train Recall:  0.6153846153846154 , Train F1score:  0.7563636363636365 , Train AUC: 0.8041835357624831
# Test Accuracy:  0.8782608695652174 , Test Precision:  0.967741935483871 , Test Recall:  0.6976744186046512 , Test F1score:  0.810810810810811 , Test AUC: 0.8418927648578811
#
# Simulation:  27
# Train Accuracy:  0.8524229074889867 , Train Precision:  0.9722222222222222 , Train Recall:  0.621301775147929 , Train F1score:  0.7581227436823104 , Train AUC: 0.8053877296792276
# Test Accuracy:  0.8434782608695652 , Test Precision:  1.0 , Test Recall:  0.5813953488372093 , Test F1score:  0.7352941176470588 , Test AUC: 0.7906976744186047
#
# Simulation:  28
# Train Accuracy:  0.8414096916299559 , Train Precision:  0.98989898989899 , Train Recall:  0.5798816568047337 , Train F1score:  0.7313432835820894 , Train AUC: 0.7881864424374545
# Test Accuracy:  0.8869565217391304 , Test Precision:  0.96875 , Test Recall:  0.7209302325581395 , Test F1score:  0.8266666666666667 , Test AUC: 0.8535206718346253
#
# Simulation:  29
# Train Accuracy:  0.8524229074889867 , Train Precision:  0.9811320754716981 , Train Recall:  0.6153846153846154 , Train F1score:  0.7563636363636365 , Train AUC: 0.8041835357624831
# Test Accuracy:  0.8782608695652174 , Test Precision:  0.967741935483871 , Test Recall:  0.6976744186046512 , Test F1score:  0.810810810810811 , Test AUC: 0.8418927648578811
#
# Simulation:  30
# Train Accuracy:  0.8810572687224669 , Train Precision:  0.9752066115702479 , Train Recall:  0.6982248520710059 , Train F1score:  0.8137931034482758 , Train AUC: 0.843849268140766
# Test Accuracy:  0.7913043478260869 , Test Precision:  1.0 , Test Recall:  0.4418604651162791 , Test F1score:  0.6129032258064516 , Test AUC: 0.7209302325581395
